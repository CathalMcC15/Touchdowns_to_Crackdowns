# %% [markdown]
# # Preparing Chicago Weather Dataset

# %% [markdown]
# We want to examine whether the weather has an effect on the type of crimes carried out in the time surrounding sports games. For example, if the weather is bad are more fans staying indoors to watch the games and in turn is domestic violence rising? Then alternatively to that, does good weather cause an increase in assault and vandalism, as more fans would be outdoor and attending the games?

# %% [markdown]
# In this notebook we will load in three datasets: one for temperature, one for weather description and one for wind speed. Each one contains data on 36 cities in the US and their columns is named after each one. We want to grade this weather so we can get an overall sense of how good or bad the weather was at certain times in the day. Each type of weather will contribute equally to determine what type of weather occurred.

# %% [markdown]
# ### Loading in the data

# %%
import os.path
import datetime
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The temperature dataset is loaded in. This contains hourly data of 36 different cities in the US. The datetime column is made the index column.

# %%
if not os.path.exists( "../../data/raw/temperature.csv" ):
    print("Missing dataset file")

# %%
temp = pd.read_csv( "../../data/raw/temperature.csv", index_col="datetime", parse_dates=True)

# %%
temp.head()
# Out:
#                       Vancouver    Portland  San Francisco     Seattle  \
# datetime
# 2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#                      Los Angeles   San Diego   Las Vegas     Phoenix  \
# datetime
# 2012-10-01 12:00:00          NaN         NaN         NaN         NaN
# 2012-10-01 13:00:00   291.870000  291.530000  293.410000  296.600000
# 2012-10-01 14:00:00   291.868186  291.533501  293.403141  296.608509
# 2012-10-01 15:00:00   291.862844  291.543355  293.392177  296.631487
# 2012-10-01 16:00:00   291.857503  291.553209  293.381213  296.654466
#
#                      Albuquerque      Denver    ...      Philadelphia  \
# datetime                                        ...
# 2012-10-01 12:00:00          NaN         NaN    ...               NaN
# 2012-10-01 13:00:00   285.120000  284.610000    ...        285.630000
# 2012-10-01 14:00:00   285.154558  284.607306    ...        285.663208
# 2012-10-01 15:00:00   285.233952  284.599918    ...        285.756824
# 2012-10-01 16:00:00   285.313345  284.592530    ...        285.850440
#
#                        New York    Montreal      Boston   Beersheba  \
# datetime
# 2012-10-01 12:00:00         NaN         NaN         NaN         NaN
# 2012-10-01 13:00:00  288.220000  285.830000  287.170000  307.590000
# 2012-10-01 14:00:00  288.247676  285.834650  287.186092  307.590000
# 2012-10-01 15:00:00  288.326940  285.847790  287.231672  307.391513
# 2012-10-01 16:00:00  288.406203  285.860929  287.277251  307.145200
#
#                      Tel Aviv District       Eilat  Haifa  Nahariyya  \
# datetime
# 2012-10-01 12:00:00                NaN  309.100000    NaN        NaN
# 2012-10-01 13:00:00         305.470000  310.580000  304.4      304.4
# 2012-10-01 14:00:00         304.310000  310.495769  304.4      304.4
# 2012-10-01 15:00:00         304.281841  310.411538  304.4      304.4
# 2012-10-01 16:00:00         304.238015  310.327308  304.4      304.4
#
#                      Jerusalem
# datetime
# 2012-10-01 12:00:00        NaN
# 2012-10-01 13:00:00      303.5
# 2012-10-01 14:00:00      303.5
# 2012-10-01 15:00:00      303.5
# 2012-10-01 16:00:00      303.5
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Chicago

# %% [markdown]
# Filtering the column from Chicago...

# %%
chi1 = temp.filter(items=['Chicago'])

# %%
chi1.head()
# Out:
#                         Chicago
# datetime
# 2012-10-01 12:00:00         NaN
# 2012-10-01 13:00:00  284.010000
# 2012-10-01 14:00:00  284.054691
# 2012-10-01 15:00:00  284.177412
# 2012-10-01 16:00:00  284.300133

# %% [markdown]
# This column is renamed to 'Temperature'. In each dataset, whether it be the temperature, wind speed or description dataset, the column is named after the city. When we would join them, for this example we would be left with three columns named Chicago.

# %%
chi1 = chi1.rename(columns={'Chicago': 'Temperature'})

# %%
chi1.head()
# Out:
#                      Temperature
# datetime
# 2012-10-01 12:00:00          NaN
# 2012-10-01 13:00:00   284.010000
# 2012-10-01 14:00:00   284.054691
# 2012-10-01 15:00:00   284.177412
# 2012-10-01 16:00:00   284.300133

# %% [markdown]
# The wind speed dataset is now loaded in...

# %%
if not os.path.exists( "../../data/raw/wind_speed.csv" ):
    print("Missing dataset file")

# %% [markdown]
# The datetime column is again made the index..

# %%
temp1 = pd.read_csv( "../../data/raw/wind_speed.csv", index_col="datetime", parse_dates=True)

# %%
temp1.head()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2012-10-01 12:00:00        NaN       NaN            NaN      NaN          NaN
# 2012-10-01 13:00:00        0.0       0.0            2.0      0.0          0.0
# 2012-10-01 14:00:00        0.0       0.0            2.0      0.0          0.0
# 2012-10-01 15:00:00        0.0       0.0            2.0      0.0          0.0
# 2012-10-01 16:00:00        0.0       0.0            2.0      0.0          0.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  \
# datetime
# 2012-10-01 12:00:00        NaN        NaN      NaN          NaN     NaN
# 2012-10-01 13:00:00        0.0        0.0      2.0          4.0     4.0
# 2012-10-01 14:00:00        0.0        0.0      2.0          4.0     4.0
# 2012-10-01 15:00:00        0.0        0.0      2.0          4.0     3.0
# 2012-10-01 16:00:00        0.0        0.0      2.0          4.0     3.0
#
#                        ...      Philadelphia  New York  Montreal  Boston  \
# datetime               ...
# 2012-10-01 12:00:00    ...               NaN       NaN       NaN     NaN
# 2012-10-01 13:00:00    ...               4.0       7.0       4.0     3.0
# 2012-10-01 14:00:00    ...               4.0       7.0       4.0     3.0
# 2012-10-01 15:00:00    ...               3.0       7.0       4.0     3.0
# 2012-10-01 16:00:00    ...               3.0       7.0       4.0     3.0
#
#                      Beersheba  Tel Aviv District  Eilat  Haifa  Nahariyya  \
# datetime
# 2012-10-01 12:00:00        NaN                NaN    8.0    NaN        NaN
# 2012-10-01 13:00:00        1.0                0.0    8.0    2.0        2.0
# 2012-10-01 14:00:00        3.0                0.0    8.0    2.0        2.0
# 2012-10-01 15:00:00        3.0                0.0    8.0    2.0        2.0
# 2012-10-01 16:00:00        3.0                0.0    8.0    2.0        2.0
#
#                      Jerusalem
# datetime
# 2012-10-01 12:00:00        NaN
# 2012-10-01 13:00:00        2.0
# 2012-10-01 14:00:00        2.0
# 2012-10-01 15:00:00        2.0
# 2012-10-01 16:00:00        2.0
#
# [5 rows x 36 columns]

# %% [markdown]
# Again only interested in the Chicago column

# %%
chi2 = temp1.filter(items=['Chicago'])

# %%
chi2.head()
# Out:
#                      Chicago
# datetime
# 2012-10-01 12:00:00      NaN
# 2012-10-01 13:00:00      0.0
# 2012-10-01 14:00:00      0.0
# 2012-10-01 15:00:00      0.0
# 2012-10-01 16:00:00      0.0

# %% [markdown]
# The Chicago column is renamed to 'Wind Speed'

# %%
chi2 = chi2.rename(columns={'Chicago': 'Wind Speed'})

# %%
chi2.head()
# Out:
#                      Wind Speed
# datetime
# 2012-10-01 12:00:00         NaN
# 2012-10-01 13:00:00         0.0
# 2012-10-01 14:00:00         0.0
# 2012-10-01 15:00:00         0.0
# 2012-10-01 16:00:00         0.0

# %% [markdown]
# The weather description dataset is loaded in..

# %%
if not os.path.exists( "../../data/raw/weather_description.csv" ):
    print("Missing dataset file")

# %% [markdown]
# datetime is again made the index..

# %%
temp2 = pd.read_csv( "../../data/raw/weather_description.csv", index_col="datetime", parse_dates=True)

# %%
temp2.head()
# Out:
#                          Vancouver          Portland San Francisco  \
# datetime
# 2012-10-01 12:00:00            NaN               NaN           NaN
# 2012-10-01 13:00:00           mist  scattered clouds    light rain
# 2012-10-01 14:00:00  broken clouds  scattered clouds  sky is clear
# 2012-10-01 15:00:00  broken clouds  scattered clouds  sky is clear
# 2012-10-01 16:00:00  broken clouds  scattered clouds  sky is clear
#
#                           Seattle   Los Angeles     San Diego     Las Vegas  \
# datetime
# 2012-10-01 12:00:00           NaN           NaN           NaN           NaN
# 2012-10-01 13:00:00  sky is clear          mist  sky is clear  sky is clear
# 2012-10-01 14:00:00  sky is clear  sky is clear  sky is clear  sky is clear
# 2012-10-01 15:00:00  sky is clear  sky is clear  sky is clear  sky is clear
# 2012-10-01 16:00:00  sky is clear  sky is clear  sky is clear  sky is clear
#
#                           Phoenix   Albuquerque         Denver  \
# datetime
# 2012-10-01 12:00:00           NaN           NaN            NaN
# 2012-10-01 13:00:00  sky is clear  sky is clear     light rain
# 2012-10-01 14:00:00  sky is clear  sky is clear  broken clouds
# 2012-10-01 15:00:00  sky is clear  sky is clear  broken clouds
# 2012-10-01 16:00:00  sky is clear  sky is clear  broken clouds
#
#                           ...          Philadelphia    New York  \
# datetime                  ...
# 2012-10-01 12:00:00       ...                   NaN         NaN
# 2012-10-01 13:00:00       ...         broken clouds  few clouds
# 2012-10-01 14:00:00       ...         broken clouds  few clouds
# 2012-10-01 15:00:00       ...         broken clouds  few clouds
# 2012-10-01 16:00:00       ...         broken clouds  few clouds
#
#                             Montreal        Boston        Beersheba  \
# datetime
# 2012-10-01 12:00:00              NaN           NaN              NaN
# 2012-10-01 13:00:00  overcast clouds  sky is clear     sky is clear
# 2012-10-01 14:00:00     sky is clear    few clouds     sky is clear
# 2012-10-01 15:00:00     sky is clear    few clouds  overcast clouds
# 2012-10-01 16:00:00     sky is clear    few clouds  overcast clouds
#
#                     Tel Aviv District          Eilat            Haifa  \
# datetime
# 2012-10-01 12:00:00               NaN           haze              NaN
# 2012-10-01 13:00:00      sky is clear           haze     sky is clear
# 2012-10-01 14:00:00      sky is clear  broken clouds  overcast clouds
# 2012-10-01 15:00:00      sky is clear  broken clouds  overcast clouds
# 2012-10-01 16:00:00      sky is clear  broken clouds  overcast clouds
#
#                            Nahariyya        Jerusalem
# datetime
# 2012-10-01 12:00:00              NaN              NaN
# 2012-10-01 13:00:00     sky is clear     sky is clear
# 2012-10-01 14:00:00     sky is clear  overcast clouds
# 2012-10-01 15:00:00  overcast clouds  overcast clouds
# 2012-10-01 16:00:00  overcast clouds  overcast clouds
#
# [5 rows x 36 columns]

# %% [markdown]
# Again, only looking at the Chicago column

# %%
chi3 = temp2.filter(items=['Chicago'])

# %%
chi3.head()
# Out:
#                              Chicago
# datetime
# 2012-10-01 12:00:00              NaN
# 2012-10-01 13:00:00  overcast clouds
# 2012-10-01 14:00:00  overcast clouds
# 2012-10-01 15:00:00  overcast clouds
# 2012-10-01 16:00:00  overcast clouds

# %% [markdown]
# This column is renamed to 'Description'

# %%
chi3 = chi3.rename(columns={'Chicago': 'Description'})

# %%
chi3.head()
# Out:
#                          Description
# datetime
# 2012-10-01 12:00:00              NaN
# 2012-10-01 13:00:00  overcast clouds
# 2012-10-01 14:00:00  overcast clouds
# 2012-10-01 15:00:00  overcast clouds
# 2012-10-01 16:00:00  overcast clouds

# %% [markdown]
# The Temperature, Wind Speed and Description columns are now concatted into the one dataframe.

# %%
frames = [chi1, chi2, chi3]
df = pd.concat(frames, axis = 1)

# %%
df.head()
# Out:
#                      Temperature  Wind Speed      Description
# datetime
# 2012-10-01 12:00:00          NaN         NaN              NaN
# 2012-10-01 13:00:00   284.010000         0.0  overcast clouds
# 2012-10-01 14:00:00   284.054691         0.0  overcast clouds
# 2012-10-01 15:00:00   284.177412         0.0  overcast clouds
# 2012-10-01 16:00:00   284.300133         0.0  overcast clouds

# %% [markdown]
# ### Dealing with Null values

# %% [markdown]
# We look at the null values in the new dataframe.

# %%
df.isnull().sum()
# Out:
# Temperature    3
# Wind Speed     1
# Description    1
# dtype: int64

# %% [markdown]
# Looking at the rows where Description is null... The only example is in the first row which is black in all fields so this row is deleted.

# %%
print(df[df["Description"].isnull()])
# Out:
#                      Temperature  Wind Speed Description
# datetime
# 2012-10-01 12:00:00          NaN         NaN         NaN

# %%
df = df.dropna(subset = ['Description'])

# %% [markdown]
# Looking at the temperature fields that are null.

# %%
print(df[df["Temperature"].isnull()])
# Out:
#                      Temperature  Wind Speed Description
# datetime
# 2013-03-11 07:00:00          NaN         1.0  light rain
# 2013-03-11 08:00:00          NaN         2.0  light rain

# %% [markdown]
# Looking at the day that consists of the null values.

# %%
testdate = df.loc['2013-03-11':'2013-03-11']

# %%
testdate
# Out:
#                      Temperature  Wind Speed      Description
# datetime
# 2013-03-11 00:00:00      278.920         5.0  overcast clouds
# 2013-03-11 01:00:00      279.005         4.0  overcast clouds
# 2013-03-11 02:00:00      279.090         4.0  overcast clouds
# 2013-03-11 03:00:00      279.380         3.0  overcast clouds
# 2013-03-11 04:00:00      280.220         3.0  overcast clouds
# 2013-03-11 05:00:00      280.380         4.0  overcast clouds
# 2013-03-11 06:00:00      280.690         3.0    broken clouds
# 2013-03-11 07:00:00          NaN         1.0       light rain
# 2013-03-11 08:00:00          NaN         2.0       light rain
# 2013-03-11 09:00:00      278.850         4.0             mist
# 2013-03-11 10:00:00      279.070         5.0       light rain
# 2013-03-11 11:00:00      279.480         4.0             mist
# 2013-03-11 12:00:00      279.080         3.0    moderate rain
# 2013-03-11 13:00:00      279.265         3.0  overcast clouds
# 2013-03-11 14:00:00      279.450         4.0             mist
# 2013-03-11 15:00:00      280.040         4.0             mist
# 2013-03-11 16:00:00      279.053         3.0  overcast clouds
# 2013-03-11 17:00:00      281.350         3.0             mist
# 2013-03-11 18:00:00      281.750         2.0     sky is clear
# 2013-03-11 19:00:00      282.150         1.0  overcast clouds
# 2013-03-11 20:00:00      282.410         1.0             mist
# 2013-03-11 21:00:00      281.900         0.0             mist
# 2013-03-11 22:00:00      278.976         4.0       light rain
# 2013-03-11 23:00:00      281.440         4.0              fog

# %% [markdown]
# Find the average between 280.690 and 278.850. This is equal to 279.770. We'll then fill the null values with this average. Instead of deleting the rows we felt this was the best solution as we could need these rows later when comparing them to the NFL and NBA games. We felt getting the average between the row after and before the missing values would give us the best result.

# %%
df['Temperature'] = df['Temperature'].fillna(279.770)

# %%
print(df[df["Temperature"].isnull()])
# Out:
# Empty DataFrame
# Columns: [Temperature, Wind Speed, Description]
# Index: []

# %% [markdown]
# We want to convert the temperature to degrees Celcius from kelvin. Celcius is more familiar to us and the general public so we felt it would make understanding easier. The formula to do this is T(°C)=T(K)-273.15, Therefore, we create a new column called 'Celcius' and use this formula.

# %%
df["Celcius"] = df["Temperature"] - 273.15

# %%
df.head()
# Out:
#                      Temperature  Wind Speed      Description    Celcius
# datetime
# 2012-10-01 13:00:00   284.010000         0.0  overcast clouds  10.860000
# 2012-10-01 14:00:00   284.054691         0.0  overcast clouds  10.904691
# 2012-10-01 15:00:00   284.177412         0.0  overcast clouds  11.027412
# 2012-10-01 16:00:00   284.300133         0.0  overcast clouds  11.150133
# 2012-10-01 17:00:00   284.422855         0.0  overcast clouds  11.272855

# %% [markdown]
# The Kelvin temperature column is now dropped as it is no longer needed

# %%
df = df.drop(df.columns[[0]], axis=1)

# %%
chiWea = df

# %%
chiWea.head()
# Out:
#                      Wind Speed      Description    Celcius
# datetime
# 2012-10-01 13:00:00         0.0  overcast clouds  10.860000
# 2012-10-01 14:00:00         0.0  overcast clouds  10.904691
# 2012-10-01 15:00:00         0.0  overcast clouds  11.027412
# 2012-10-01 16:00:00         0.0  overcast clouds  11.150133
# 2012-10-01 17:00:00         0.0  overcast clouds  11.272855

# %% [markdown]
# ### The Weather Grading System

# %% [markdown]
# We now look at all the different types of Weather in terms of description. These will be grouped into different groups depending how good the weather is.

# %%
pt = chiWea.groupby('Description')[('Celcius')].count()
pt.sort_values(ascending = False)
# Out:
# Description
# sky is clear                           10844
# broken clouds                           7255
# overcast clouds                         5412
# scattered clouds                        4522
# mist                                    4112
# few clouds                              3851
# light rain                              3745
# moderate rain                           1469
# light snow                               886
# haze                                     877
# fog                                      530
# heavy intensity rain                     503
# snow                                     241
# light intensity drizzle                  228
# heavy snow                               196
# proximity thunderstorm                   178
# drizzle                                  143
# thunderstorm                              78
# thunderstorm with light rain              60
# very heavy rain                           35
# thunderstorm with rain                    27
# thunderstorm with heavy rain              20
# proximity thunderstorm with rain          12
# heavy intensity drizzle                    7
# freezing rain                              5
# proximity thunderstorm with drizzle        4
# light rain and snow                        3
# proximity shower rain                      2
# dust                                       2
# thunderstorm with drizzle                  2
# smoke                                      1
# squalls                                    1
# thunderstorm with light drizzle            1
# Name: Celcius, dtype: int64

# %% [markdown]
# We create the following function. If the description is 'sky is clear' or 'few clouds' this weather is considered good and is given a value of 3. Then if the description is 'overcast clouds', 'broken clouds' or 'scattered clouds' the weather is considered to be moderate and is given a value of 2. The rest (the bad weather) is given a value of 0. We wanted to get a clear difference between good and even moderate weather which is why bad weather is valued at 0 instead of 1.

# %%
conditions = [
    (chiWea['Description'] == 'sky is clear') | (chiWea['Description'] == 'few clouds'),
    (chiWea['Description'] == 'overcast clouds') | (chiWea['Description'] == 'broken clouds') 
    | (chiWea['Description'] == 'scattered clouds') ]
choices = ['3', '2']
chiWea['DescRate'] = np.select(conditions, choices, default='0')
print(chiWea)
# Out:
#                      Wind Speed       Description    Celcius DescRate
# datetime
# 2012-10-01 13:00:00         0.0   overcast clouds  10.860000        2
# 2012-10-01 14:00:00         0.0   overcast clouds  10.904691        2
# 2012-10-01 15:00:00         0.0   overcast clouds  11.027412        2
# 2012-10-01 16:00:00         0.0   overcast clouds  11.150133        2
# 2012-10-01 17:00:00         0.0   overcast clouds  11.272855        2
# 2012-10-01 18:00:00         0.0   overcast clouds  11.395576        2
# 2012-10-01 19:00:00         0.0   overcast clouds  11.518297        2
# 2012-10-01 20:00:00         0.0   overcast clouds  11.641018        2
# 2012-10-01 21:00:00         0.0   overcast clouds  11.763739        2
# 2012-10-01 22:00:00         0.0   overcast clouds  11.886461        2
# 2012-10-01 23:00:00         0.0   overcast clouds  12.009182        2
# 2012-10-02 00:00:00         0.0   overcast clouds  12.131903        2
# 2012-10-02 01:00:00         0.0   overcast clouds  12.254624        2
# 2012-10-02 02:00:00         0.0   overcast clouds  12.377345        2
# 2012-10-02 03:00:00         0.0   overcast clouds  12.500067        2
# 2012-10-02 04:00:00         0.0   overcast clouds  12.622788        2
# 2012-10-02 05:00:00         0.0   overcast clouds  12.745509        2
# 2012-10-02 06:00:00         0.0   overcast clouds  12.868230        2
# 2012-10-02 07:00:00         0.0   overcast clouds  12.990952        2
# 2012-10-02 08:00:00         0.0   overcast clouds  13.113673        2
# 2012-10-02 09:00:00         0.0   overcast clouds  13.236394        2
# 2012-10-02 10:00:00         0.0   overcast clouds  13.359115        2
# 2012-10-02 11:00:00         0.0   overcast clouds  13.481836        2
# 2012-10-02 12:00:00         0.0   overcast clouds  13.604558        2
# 2012-10-02 13:00:00         0.0   overcast clouds  13.727279        2
# 2012-10-02 14:00:00         0.0   overcast clouds  13.850000        2
# 2012-10-02 15:00:00         0.0   overcast clouds  16.150000        2
# 2012-10-02 16:00:00         0.0      sky is clear  16.700000        3
# 2012-10-02 17:00:00         2.0      sky is clear  17.770000        3
# 2012-10-02 18:00:00         2.0   overcast clouds  18.100000        2
# ...                         ...               ...        ...      ...
# 2017-11-28 19:00:00         8.0   overcast clouds  15.900000        2
# 2017-11-28 20:00:00         6.0   overcast clouds  16.170000        2
# 2017-11-28 21:00:00         7.0     broken clouds  16.390000        2
# 2017-11-28 22:00:00         8.0   overcast clouds  15.800000        2
# 2017-11-28 23:00:00         8.0   overcast clouds  16.240000        2
# 2017-11-29 00:00:00         5.0   overcast clouds  13.890000        2
# 2017-11-29 01:00:00         3.0        light rain  12.800000        0
# 2017-11-29 02:00:00         2.0     broken clouds  11.360000        2
# 2017-11-29 03:00:00         2.0      sky is clear   9.810000        3
# 2017-11-29 04:00:00         6.0  scattered clouds   8.890000        2
# 2017-11-29 05:00:00         4.0      sky is clear   8.110000        3
# 2017-11-29 06:00:00         3.0      sky is clear   6.910000        3
# 2017-11-29 07:00:00         4.0      sky is clear   6.290000        3
# 2017-11-29 08:00:00         3.0      sky is clear   4.540000        3
# 2017-11-29 09:00:00         3.0      sky is clear   4.010000        3
# 2017-11-29 10:00:00         6.0      sky is clear   2.820000        3
# 2017-11-29 11:00:00         6.0      sky is clear   0.820000        3
# 2017-11-29 12:00:00         6.0      sky is clear   0.930000        3
# 2017-11-29 13:00:00         5.0      sky is clear   0.630000        3
# 2017-11-29 14:00:00         4.0      sky is clear   0.110000        3
# 2017-11-29 15:00:00         4.0      sky is clear   2.060000        3
# 2017-11-29 16:00:00         4.0      sky is clear   4.880000        3
# 2017-11-29 17:00:00         4.0      sky is clear   6.430000        3
# 2017-11-29 18:00:00         3.0        few clouds   7.160000        3
# 2017-11-29 19:00:00         3.0        few clouds   7.900000        3
# 2017-11-29 20:00:00         2.0        few clouds   8.190000        3
# 2017-11-29 21:00:00         4.0      sky is clear   8.540000        3
# 2017-11-29 22:00:00         2.0        few clouds   7.920000        3
# 2017-11-29 23:00:00         2.0      sky is clear   6.910000        3
# 2017-11-30 00:00:00         5.0      sky is clear   5.310000        3
#
# [45252 rows x 4 columns]

# %% [markdown]
# The next thing was to determine how good the temperatue was, so we could assign it a grade. We first got the mean temperature. Anything below the average temperature would be considered to be 'bad weather'.

# %%
chiWea['Celcius'].mean()
# Out:
# 10.200414543717171

# %% [markdown]
# Again the same type of code is used as above. This time if the temperature is below or equal to 10 a value of 0 is assigned as it is considered bad weather. Anything above or equal to 20 degrees celcius is given a value of 3 as it is good weather. The In between temperatures are considered moderate and is given a value of 2.

# %%
conditions = [
    (chiWea['Celcius'] <= 10),
    (chiWea['Celcius'] >= 20)]
choices = ['0', '3']
chiWea['TempRate'] = np.select(conditions, choices, default='2')
print(chiWea)
# Out:
#                      Wind Speed       Description    Celcius DescRate TempRate
# datetime
# 2012-10-01 13:00:00         0.0   overcast clouds  10.860000        2        2
# 2012-10-01 14:00:00         0.0   overcast clouds  10.904691        2        2
# 2012-10-01 15:00:00         0.0   overcast clouds  11.027412        2        2
# 2012-10-01 16:00:00         0.0   overcast clouds  11.150133        2        2
# 2012-10-01 17:00:00         0.0   overcast clouds  11.272855        2        2
# 2012-10-01 18:00:00         0.0   overcast clouds  11.395576        2        2
# 2012-10-01 19:00:00         0.0   overcast clouds  11.518297        2        2
# 2012-10-01 20:00:00         0.0   overcast clouds  11.641018        2        2
# 2012-10-01 21:00:00         0.0   overcast clouds  11.763739        2        2
# 2012-10-01 22:00:00         0.0   overcast clouds  11.886461        2        2
# 2012-10-01 23:00:00         0.0   overcast clouds  12.009182        2        2
# 2012-10-02 00:00:00         0.0   overcast clouds  12.131903        2        2
# 2012-10-02 01:00:00         0.0   overcast clouds  12.254624        2        2
# 2012-10-02 02:00:00         0.0   overcast clouds  12.377345        2        2
# 2012-10-02 03:00:00         0.0   overcast clouds  12.500067        2        2
# 2012-10-02 04:00:00         0.0   overcast clouds  12.622788        2        2
# 2012-10-02 05:00:00         0.0   overcast clouds  12.745509        2        2
# 2012-10-02 06:00:00         0.0   overcast clouds  12.868230        2        2
# 2012-10-02 07:00:00         0.0   overcast clouds  12.990952        2        2
# 2012-10-02 08:00:00         0.0   overcast clouds  13.113673        2        2
# 2012-10-02 09:00:00         0.0   overcast clouds  13.236394        2        2
# 2012-10-02 10:00:00         0.0   overcast clouds  13.359115        2        2
# 2012-10-02 11:00:00         0.0   overcast clouds  13.481836        2        2
# 2012-10-02 12:00:00         0.0   overcast clouds  13.604558        2        2
# 2012-10-02 13:00:00         0.0   overcast clouds  13.727279        2        2
# 2012-10-02 14:00:00         0.0   overcast clouds  13.850000        2        2
# 2012-10-02 15:00:00         0.0   overcast clouds  16.150000        2        2
# 2012-10-02 16:00:00         0.0      sky is clear  16.700000        3        2
# 2012-10-02 17:00:00         2.0      sky is clear  17.770000        3        2
# 2012-10-02 18:00:00         2.0   overcast clouds  18.100000        2        2
# ...                         ...               ...        ...      ...      ...
# 2017-11-28 19:00:00         8.0   overcast clouds  15.900000        2        2
# 2017-11-28 20:00:00         6.0   overcast clouds  16.170000        2        2
# 2017-11-28 21:00:00         7.0     broken clouds  16.390000        2        2
# 2017-11-28 22:00:00         8.0   overcast clouds  15.800000        2        2
# 2017-11-28 23:00:00         8.0   overcast clouds  16.240000        2        2
# 2017-11-29 00:00:00         5.0   overcast clouds  13.890000        2        2
# 2017-11-29 01:00:00         3.0        light rain  12.800000        0        2
# 2017-11-29 02:00:00         2.0     broken clouds  11.360000        2        2
# 2017-11-29 03:00:00         2.0      sky is clear   9.810000        3        0
# 2017-11-29 04:00:00         6.0  scattered clouds   8.890000        2        0
# 2017-11-29 05:00:00         4.0      sky is clear   8.110000        3        0
# 2017-11-29 06:00:00         3.0      sky is clear   6.910000        3        0
# 2017-11-29 07:00:00         4.0      sky is clear   6.290000        3        0
# 2017-11-29 08:00:00         3.0      sky is clear   4.540000        3        0
# 2017-11-29 09:00:00         3.0      sky is clear   4.010000        3        0
# 2017-11-29 10:00:00         6.0      sky is clear   2.820000        3        0
# 2017-11-29 11:00:00         6.0      sky is clear   0.820000        3        0
# 2017-11-29 12:00:00         6.0      sky is clear   0.930000        3        0
# 2017-11-29 13:00:00         5.0      sky is clear   0.630000        3        0
# 2017-11-29 14:00:00         4.0      sky is clear   0.110000        3        0
# 2017-11-29 15:00:00         4.0      sky is clear   2.060000        3        0
# 2017-11-29 16:00:00         4.0      sky is clear   4.880000        3        0
# 2017-11-29 17:00:00         4.0      sky is clear   6.430000        3        0
# 2017-11-29 18:00:00         3.0        few clouds   7.160000        3        0
# 2017-11-29 19:00:00         3.0        few clouds   7.900000        3        0
# 2017-11-29 20:00:00         2.0        few clouds   8.190000        3        0
# 2017-11-29 21:00:00         4.0      sky is clear   8.540000        3        0
# 2017-11-29 22:00:00         2.0        few clouds   7.920000        3        0
# 2017-11-29 23:00:00         2.0      sky is clear   6.910000        3        0
# 2017-11-30 00:00:00         5.0      sky is clear   5.310000        3        0
#
# [45252 rows x 5 columns]

# %%
chiWea.head()
# Out:
#                      Wind Speed      Description    Celcius DescRate TempRate
# datetime
# 2012-10-01 13:00:00         0.0  overcast clouds  10.860000        2        2
# 2012-10-01 14:00:00         0.0  overcast clouds  10.904691        2        2
# 2012-10-01 15:00:00         0.0  overcast clouds  11.027412        2        2
# 2012-10-01 16:00:00         0.0  overcast clouds  11.150133        2        2
# 2012-10-01 17:00:00         0.0  overcast clouds  11.272855        2        2

# %% [markdown]
# The average wind speed is found. This is relatively low. Although there is no indication to what the wind speed is measured in we are inclined to think the measurement is knots. The average wind speed in Chicago is around 6-10km per hour according to https://www.isws.illinois.edu/statecli/wind/wind.htm . This average in knots would fit into this bracket.

# %%
chiWea['Wind Speed'].mean()
# Out:
# 3.7593255546716167

# %% [markdown]
# Wind speed less than or equal to 2 is considered to be very calm and is considered good. It is valued at 3. Between 2 and 5 is considered moderate and is valued at 2. Above 5 knots is considered bad and is given a value of 0.

# %%
conditions = [
    (chiWea['Wind Speed'] <= 2),
    (chiWea['Wind Speed'] > 2) | (chiWea['Wind Speed'] < 5) ]
choices = ['3', '2']
chiWea['WindRate'] = np.select(conditions, choices, default='0')
print(chiWea)
# Out:
#                      Wind Speed       Description    Celcius DescRate  \
# datetime
# 2012-10-01 13:00:00         0.0   overcast clouds  10.860000        2
# 2012-10-01 14:00:00         0.0   overcast clouds  10.904691        2
# 2012-10-01 15:00:00         0.0   overcast clouds  11.027412        2
# 2012-10-01 16:00:00         0.0   overcast clouds  11.150133        2
# 2012-10-01 17:00:00         0.0   overcast clouds  11.272855        2
# 2012-10-01 18:00:00         0.0   overcast clouds  11.395576        2
# 2012-10-01 19:00:00         0.0   overcast clouds  11.518297        2
# 2012-10-01 20:00:00         0.0   overcast clouds  11.641018        2
# 2012-10-01 21:00:00         0.0   overcast clouds  11.763739        2
# 2012-10-01 22:00:00         0.0   overcast clouds  11.886461        2
# 2012-10-01 23:00:00         0.0   overcast clouds  12.009182        2
# 2012-10-02 00:00:00         0.0   overcast clouds  12.131903        2
# 2012-10-02 01:00:00         0.0   overcast clouds  12.254624        2
# 2012-10-02 02:00:00         0.0   overcast clouds  12.377345        2
# 2012-10-02 03:00:00         0.0   overcast clouds  12.500067        2
# 2012-10-02 04:00:00         0.0   overcast clouds  12.622788        2
# 2012-10-02 05:00:00         0.0   overcast clouds  12.745509        2
# 2012-10-02 06:00:00         0.0   overcast clouds  12.868230        2
# 2012-10-02 07:00:00         0.0   overcast clouds  12.990952        2
# 2012-10-02 08:00:00         0.0   overcast clouds  13.113673        2
# 2012-10-02 09:00:00         0.0   overcast clouds  13.236394        2
# 2012-10-02 10:00:00         0.0   overcast clouds  13.359115        2
# 2012-10-02 11:00:00         0.0   overcast clouds  13.481836        2
# 2012-10-02 12:00:00         0.0   overcast clouds  13.604558        2
# 2012-10-02 13:00:00         0.0   overcast clouds  13.727279        2
# 2012-10-02 14:00:00         0.0   overcast clouds  13.850000        2
# 2012-10-02 15:00:00         0.0   overcast clouds  16.150000        2
# 2012-10-02 16:00:00         0.0      sky is clear  16.700000        3
# 2012-10-02 17:00:00         2.0      sky is clear  17.770000        3
# 2012-10-02 18:00:00         2.0   overcast clouds  18.100000        2
# ...                         ...               ...        ...      ...
# 2017-11-28 19:00:00         8.0   overcast clouds  15.900000        2
# 2017-11-28 20:00:00         6.0   overcast clouds  16.170000        2
# 2017-11-28 21:00:00         7.0     broken clouds  16.390000        2
# 2017-11-28 22:00:00         8.0   overcast clouds  15.800000        2
# 2017-11-28 23:00:00         8.0   overcast clouds  16.240000        2
# 2017-11-29 00:00:00         5.0   overcast clouds  13.890000        2
# 2017-11-29 01:00:00         3.0        light rain  12.800000        0
# 2017-11-29 02:00:00         2.0     broken clouds  11.360000        2
# 2017-11-29 03:00:00         2.0      sky is clear   9.810000        3
# 2017-11-29 04:00:00         6.0  scattered clouds   8.890000        2
# 2017-11-29 05:00:00         4.0      sky is clear   8.110000        3
# 2017-11-29 06:00:00         3.0      sky is clear   6.910000        3
# 2017-11-29 07:00:00         4.0      sky is clear   6.290000        3
# 2017-11-29 08:00:00         3.0      sky is clear   4.540000        3
# 2017-11-29 09:00:00         3.0      sky is clear   4.010000        3
# 2017-11-29 10:00:00         6.0      sky is clear   2.820000        3
# 2017-11-29 11:00:00         6.0      sky is clear   0.820000        3
# 2017-11-29 12:00:00         6.0      sky is clear   0.930000        3
# 2017-11-29 13:00:00         5.0      sky is clear   0.630000        3
# 2017-11-29 14:00:00         4.0      sky is clear   0.110000        3
# 2017-11-29 15:00:00         4.0      sky is clear   2.060000        3
# 2017-11-29 16:00:00         4.0      sky is clear   4.880000        3
# 2017-11-29 17:00:00         4.0      sky is clear   6.430000        3
# 2017-11-29 18:00:00         3.0        few clouds   7.160000        3
# 2017-11-29 19:00:00         3.0        few clouds   7.900000        3
# 2017-11-29 20:00:00         2.0        few clouds   8.190000        3
# 2017-11-29 21:00:00         4.0      sky is clear   8.540000        3
# 2017-11-29 22:00:00         2.0        few clouds   7.920000        3
# 2017-11-29 23:00:00         2.0      sky is clear   6.910000        3
# 2017-11-30 00:00:00         5.0      sky is clear   5.310000        3
#
#                     TempRate WindRate
# datetime
# 2012-10-01 13:00:00        2        3
# 2012-10-01 14:00:00        2        3
# 2012-10-01 15:00:00        2        3
# 2012-10-01 16:00:00        2        3
# 2012-10-01 17:00:00        2        3
# 2012-10-01 18:00:00        2        3
# 2012-10-01 19:00:00        2        3
# 2012-10-01 20:00:00        2        3
# 2012-10-01 21:00:00        2        3
# 2012-10-01 22:00:00        2        3
# 2012-10-01 23:00:00        2        3
# 2012-10-02 00:00:00        2        3
# 2012-10-02 01:00:00        2        3
# 2012-10-02 02:00:00        2        3
# 2012-10-02 03:00:00        2        3
# 2012-10-02 04:00:00        2        3
# 2012-10-02 05:00:00        2        3
# 2012-10-02 06:00:00        2        3
# 2012-10-02 07:00:00        2        3
# 2012-10-02 08:00:00        2        3
# 2012-10-02 09:00:00        2        3
# 2012-10-02 10:00:00        2        3
# 2012-10-02 11:00:00        2        3
# 2012-10-02 12:00:00        2        3
# 2012-10-02 13:00:00        2        3
# 2012-10-02 14:00:00        2        3
# 2012-10-02 15:00:00        2        3
# 2012-10-02 16:00:00        2        3
# 2012-10-02 17:00:00        2        3
# 2012-10-02 18:00:00        2        3
# ...                      ...      ...
# 2017-11-28 19:00:00        2        2
# 2017-11-28 20:00:00        2        2
# 2017-11-28 21:00:00        2        2
# 2017-11-28 22:00:00        2        2
# 2017-11-28 23:00:00        2        2
# 2017-11-29 00:00:00        2        2
# 2017-11-29 01:00:00        2        2
# 2017-11-29 02:00:00        2        3
# 2017-11-29 03:00:00        0        3
# 2017-11-29 04:00:00        0        2
# 2017-11-29 05:00:00        0        2
# 2017-11-29 06:00:00        0        2
# 2017-11-29 07:00:00        0        2
# 2017-11-29 08:00:00        0        2
# 2017-11-29 09:00:00        0        2
# 2017-11-29 10:00:00        0        2
# 2017-11-29 11:00:00        0        2
# 2017-11-29 12:00:00        0        2
# 2017-11-29 13:00:00        0        2
# 2017-11-29 14:00:00        0        2
# 2017-11-29 15:00:00        0        2
# 2017-11-29 16:00:00        0        2
# 2017-11-29 17:00:00        0        2
# 2017-11-29 18:00:00        0        2
# 2017-11-29 19:00:00        0        2
# 2017-11-29 20:00:00        0        3
# 2017-11-29 21:00:00        0        2
# 2017-11-29 22:00:00        0        3
# 2017-11-29 23:00:00        0        3
# 2017-11-30 00:00:00        0        2
#
# [45252 rows x 6 columns]

# %%
chiWea.head()
# Out:
#                      Wind Speed      Description    Celcius DescRate TempRate  \
# datetime
# 2012-10-01 13:00:00         0.0  overcast clouds  10.860000        2        2
# 2012-10-01 14:00:00         0.0  overcast clouds  10.904691        2        2
# 2012-10-01 15:00:00         0.0  overcast clouds  11.027412        2        2
# 2012-10-01 16:00:00         0.0  overcast clouds  11.150133        2        2
# 2012-10-01 17:00:00         0.0  overcast clouds  11.272855        2        2
#
#                     WindRate
# datetime
# 2012-10-01 13:00:00        3
# 2012-10-01 14:00:00        3
# 2012-10-01 15:00:00        3
# 2012-10-01 16:00:00        3
# 2012-10-01 17:00:00        3

# %%
chiWea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45252 entries, 2012-10-01 13:00:00 to 2017-11-30 00:00:00
# Freq: H
# Data columns (total 6 columns):
# Wind Speed     45252 non-null float64
# Description    45252 non-null object
# Celcius        45252 non-null float64
# DescRate       45252 non-null object
# TempRate       45252 non-null object
# WindRate       45252 non-null object
# dtypes: float64(2), object(4)
# memory usage: 3.7+ MB

# %% [markdown]
# We have to change our new columns to int as we are going to add them together to get our overall weather rating.

# %%
chiWea['DescRate'] = chiWea['DescRate'].astype(int)

# %%
chiWea['TempRate'] = chiWea['TempRate'].astype(int)

# %%
chiWea['WindRate'] = chiWea['WindRate'].astype(int)

# %%
chiWea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45252 entries, 2012-10-01 13:00:00 to 2017-11-30 00:00:00
# Freq: H
# Data columns (total 6 columns):
# Wind Speed     45252 non-null float64
# Description    45252 non-null object
# Celcius        45252 non-null float64
# DescRate       45252 non-null int32
# TempRate       45252 non-null int32
# WindRate       45252 non-null int32
# dtypes: float64(2), int32(3), object(1)
# memory usage: 3.1+ MB

# %% [markdown]
# The Overall column is created it consits of the Description Rating, Temperature Rating and Wind Rating added together. This overall rating gives us a sense of how good the weather was for that hour.

# %%
chiWea['Overall'] = chiWea["DescRate"] + chiWea["TempRate"] + chiWea["WindRate"]

# %%
chiWea.head()
# Out:
#                      Wind Speed      Description    Celcius  DescRate  \
# datetime
# 2012-10-01 13:00:00         0.0  overcast clouds  10.860000         2
# 2012-10-01 14:00:00         0.0  overcast clouds  10.904691         2
# 2012-10-01 15:00:00         0.0  overcast clouds  11.027412         2
# 2012-10-01 16:00:00         0.0  overcast clouds  11.150133         2
# 2012-10-01 17:00:00         0.0  overcast clouds  11.272855         2
#
#                      TempRate  WindRate  Overall
# datetime
# 2012-10-01 13:00:00         2         3        7
# 2012-10-01 14:00:00         2         3        7
# 2012-10-01 15:00:00         2         3        7
# 2012-10-01 16:00:00         2         3        7
# 2012-10-01 17:00:00         2         3        7

# %% [markdown]
# We then want to group the weather into Good, Moderate and Overall Weather. 8 and over is Good. 6 to 8 is considered moderate. And under 6 would be considered to be Bad. For example if we have a case where the temperature is 21 degrees, overcast clouds and rain, this would be considered bad as Raining is always considered bad in terms of weather, and prevents people from going outside.

# %%
conditions = [
    (chiWea['Overall'] >= 8), 
    (chiWea['Overall'] >= 6) & (chiWea['Overall'] < 8) ]
choices = ['Good', 'Moderate']
chiWea['Weather'] = np.select(conditions, choices, default='Bad')

# %%
chiWea.head(50)
# Out:
#                      Wind Speed       Description    Celcius  DescRate  \
# datetime
# 2012-10-01 13:00:00         0.0   overcast clouds  10.860000         2
# 2012-10-01 14:00:00         0.0   overcast clouds  10.904691         2
# 2012-10-01 15:00:00         0.0   overcast clouds  11.027412         2
# 2012-10-01 16:00:00         0.0   overcast clouds  11.150133         2
# 2012-10-01 17:00:00         0.0   overcast clouds  11.272855         2
# 2012-10-01 18:00:00         0.0   overcast clouds  11.395576         2
# 2012-10-01 19:00:00         0.0   overcast clouds  11.518297         2
# 2012-10-01 20:00:00         0.0   overcast clouds  11.641018         2
# 2012-10-01 21:00:00         0.0   overcast clouds  11.763739         2
# 2012-10-01 22:00:00         0.0   overcast clouds  11.886461         2
# 2012-10-01 23:00:00         0.0   overcast clouds  12.009182         2
# 2012-10-02 00:00:00         0.0   overcast clouds  12.131903         2
# 2012-10-02 01:00:00         0.0   overcast clouds  12.254624         2
# 2012-10-02 02:00:00         0.0   overcast clouds  12.377345         2
# 2012-10-02 03:00:00         0.0   overcast clouds  12.500067         2
# 2012-10-02 04:00:00         0.0   overcast clouds  12.622788         2
# 2012-10-02 05:00:00         0.0   overcast clouds  12.745509         2
# 2012-10-02 06:00:00         0.0   overcast clouds  12.868230         2
# 2012-10-02 07:00:00         0.0   overcast clouds  12.990952         2
# 2012-10-02 08:00:00         0.0   overcast clouds  13.113673         2
# 2012-10-02 09:00:00         0.0   overcast clouds  13.236394         2
# 2012-10-02 10:00:00         0.0   overcast clouds  13.359115         2
# 2012-10-02 11:00:00         0.0   overcast clouds  13.481836         2
# 2012-10-02 12:00:00         0.0   overcast clouds  13.604558         2
# 2012-10-02 13:00:00         0.0   overcast clouds  13.727279         2
# 2012-10-02 14:00:00         0.0   overcast clouds  13.850000         2
# 2012-10-02 15:00:00         0.0   overcast clouds  16.150000         2
# 2012-10-02 16:00:00         0.0      sky is clear  16.700000         3
# 2012-10-02 17:00:00         2.0      sky is clear  17.770000         3
# 2012-10-02 18:00:00         2.0   overcast clouds  18.100000         2
# 2012-10-02 19:00:00         0.0      sky is clear  18.030000         3
# 2012-10-02 20:00:00         0.0      sky is clear  17.700000         3
# 2012-10-02 21:00:00         0.0      sky is clear  17.400000         3
# 2012-10-02 22:00:00         4.0   overcast clouds  16.840000         2
# 2012-10-02 23:00:00         3.0   overcast clouds  15.970000         2
# 2012-10-03 00:00:00         4.0   overcast clouds  14.930000         2
# 2012-10-03 01:00:00         3.0   overcast clouds  14.790000         2
# 2012-10-03 02:00:00         2.0   overcast clouds  14.160000         2
# 2012-10-03 03:00:00         3.0   overcast clouds  13.940000         2
# 2012-10-03 04:00:00         3.0   overcast clouds  13.550000         2
# 2012-10-03 05:00:00         2.0   overcast clouds  13.720000         2
# 2012-10-03 06:00:00         3.0     broken clouds  13.720000         2
# 2012-10-03 07:00:00         3.0   overcast clouds  13.410000         2
# 2012-10-03 08:00:00         2.0      sky is clear  13.410000         3
# 2012-10-03 09:00:00         4.0   overcast clouds  13.490000         2
# 2012-10-03 10:00:00         3.0   overcast clouds  13.410000         2
# 2012-10-03 11:00:00         0.0      sky is clear  13.230000         3
# 2012-10-03 12:00:00         2.0   overcast clouds  14.160000         2
# 2012-10-03 13:00:00         5.0     broken clouds  15.090000         2
# 2012-10-03 14:00:00         6.0  scattered clouds  17.430000         2
#
#                      TempRate  WindRate  Overall   Weather
# datetime
# 2012-10-01 13:00:00         2         3        7  Moderate
# 2012-10-01 14:00:00         2         3        7  Moderate
# 2012-10-01 15:00:00         2         3        7  Moderate
# 2012-10-01 16:00:00         2         3        7  Moderate
# 2012-10-01 17:00:00         2         3        7  Moderate
# 2012-10-01 18:00:00         2         3        7  Moderate
# 2012-10-01 19:00:00         2         3        7  Moderate
# 2012-10-01 20:00:00         2         3        7  Moderate
# 2012-10-01 21:00:00         2         3        7  Moderate
# 2012-10-01 22:00:00         2         3        7  Moderate
# 2012-10-01 23:00:00         2         3        7  Moderate
# 2012-10-02 00:00:00         2         3        7  Moderate
# 2012-10-02 01:00:00         2         3        7  Moderate
# 2012-10-02 02:00:00         2         3        7  Moderate
# 2012-10-02 03:00:00         2         3        7  Moderate
# 2012-10-02 04:00:00         2         3        7  Moderate
# 2012-10-02 05:00:00         2         3        7  Moderate
# 2012-10-02 06:00:00         2         3        7  Moderate
# 2012-10-02 07:00:00         2         3        7  Moderate
# 2012-10-02 08:00:00         2         3        7  Moderate
# 2012-10-02 09:00:00         2         3        7  Moderate
# 2012-10-02 10:00:00         2         3        7  Moderate
# 2012-10-02 11:00:00         2         3        7  Moderate
# 2012-10-02 12:00:00         2         3        7  Moderate
# 2012-10-02 13:00:00         2         3        7  Moderate
# 2012-10-02 14:00:00         2         3        7  Moderate
# 2012-10-02 15:00:00         2         3        7  Moderate
# 2012-10-02 16:00:00         2         3        8      Good
# 2012-10-02 17:00:00         2         3        8      Good
# 2012-10-02 18:00:00         2         3        7  Moderate
# 2012-10-02 19:00:00         2         3        8      Good
# 2012-10-02 20:00:00         2         3        8      Good
# 2012-10-02 21:00:00         2         3        8      Good
# 2012-10-02 22:00:00         2         2        6  Moderate
# 2012-10-02 23:00:00         2         2        6  Moderate
# 2012-10-03 00:00:00         2         2        6  Moderate
# 2012-10-03 01:00:00         2         2        6  Moderate
# 2012-10-03 02:00:00         2         3        7  Moderate
# 2012-10-03 03:00:00         2         2        6  Moderate
# 2012-10-03 04:00:00         2         2        6  Moderate
# 2012-10-03 05:00:00         2         3        7  Moderate
# 2012-10-03 06:00:00         2         2        6  Moderate
# 2012-10-03 07:00:00         2         2        6  Moderate
# 2012-10-03 08:00:00         2         3        8      Good
# 2012-10-03 09:00:00         2         2        6  Moderate
# 2012-10-03 10:00:00         2         2        6  Moderate
# 2012-10-03 11:00:00         2         3        8      Good
# 2012-10-03 12:00:00         2         3        7  Moderate
# 2012-10-03 13:00:00         2         2        6  Moderate
# 2012-10-03 14:00:00         2         2        6  Moderate

# %%
chiWea.sort_values(by=['Overall'])
# Out:
#                      Wind Speed      Description    Celcius  DescRate  \
# datetime
# 2016-04-26 12:00:00         6.0              fog   7.350000         0
# 2016-02-27 15:00:00         6.0             haze   0.640000         0
# 2015-01-03 16:00:00         3.0    moderate rain   0.855667         0
# 2013-05-24 14:00:00         9.0             mist   8.690000         0
# 2014-03-19 00:00:00         6.0  very heavy rain   7.930000         0
# 2014-03-19 01:00:00         4.0  very heavy rain   7.400000         0
# 2015-01-04 02:00:00         3.0       light rain   2.110667         0
# 2014-03-19 08:00:00         5.0       light rain   6.540000         0
# 2015-01-04 04:00:00         3.0       light rain   2.397000         0
# 2014-03-19 09:00:00         4.0       light rain   6.170000         0
# 2014-03-19 11:00:00         3.0       light rain   5.950000         0
# 2014-03-19 12:00:00         3.0    moderate rain   6.120000         0
# 2014-03-19 13:00:00         3.0    moderate rain   6.280000         0
# 2015-01-04 05:00:00         3.0       light rain   2.474000         0
# 2014-03-19 14:00:00         4.0    moderate rain   6.610000         0
# 2014-03-19 15:00:00         3.0       light rain   6.640000         0
# 2014-03-19 16:00:00         4.0       light rain   6.290000         0
# 2015-01-04 06:00:00         3.0       light rain   2.295500         0
# 2014-03-19 17:00:00         5.0       light rain   4.790000         0
# 2014-03-19 23:00:00         8.0       light rain   3.070000         0
# 2014-03-20 00:00:00         7.0       light rain   2.490000         0
# 2014-03-20 01:00:00         7.0       light rain   2.190000         0
# 2014-03-20 03:00:00         6.0       light rain   1.570000         0
# 2015-01-04 09:00:00         4.0       light rain   1.704000         0
# 2015-01-03 14:00:00         4.0       light rain   0.367333         0
# 2014-03-20 04:00:00         6.0       light rain   1.300000         0
# 2015-01-03 13:00:00         4.0       light rain  -0.027333         0
# 2015-01-03 12:00:00         4.0       light rain   0.184000         0
# 2016-03-01 05:00:00         7.0       light snow  -0.718576         0
# 2017-03-04 09:00:00         5.0             mist  -1.780000         0
# ...                         ...              ...        ...       ...
# 2014-05-25 20:00:00         0.0       few clouds  27.680000         3
# 2014-07-30 01:00:00         2.0       few clouds  21.924000         3
# 2017-07-24 04:00:00         2.0     sky is clear  21.170000         3
# 2014-07-30 16:00:00         2.0       few clouds  23.490000         3
# 2014-08-20 05:00:00         2.0       few clouds  21.597333         3
# 2014-08-20 06:00:00         2.0       few clouds  21.647500         3
# 2014-08-20 07:00:00         2.0     sky is clear  21.150333         3
# 2014-08-20 08:00:00         2.0     sky is clear  21.063667         3
# 2014-08-20 09:00:00         2.0     sky is clear  20.796000         3
# 2014-08-20 10:00:00         2.0     sky is clear  20.769667         3
# 2014-08-20 11:00:00         2.0     sky is clear  20.562333         3
# 2013-09-10 03:00:00         1.0       few clouds  29.890000         3
# 2014-08-20 12:00:00         2.0     sky is clear  22.037500         3
# 2014-05-24 17:00:00         1.0       few clouds  20.190000         3
# 2014-05-25 18:00:00         2.0       few clouds  26.680000         3
# 2014-05-24 18:00:00         2.0       few clouds  21.610000         3
# 2014-05-24 19:00:00         1.0       few clouds  21.890000         3
# 2014-08-20 14:00:00         2.0     sky is clear  22.183667         3
# 2014-05-24 20:00:00         0.0       few clouds  22.490000         3
# 2014-05-24 21:00:00         1.0       few clouds  21.990000         3
# 2014-05-24 22:00:00         1.0       few clouds  21.520000         3
# 2014-05-24 23:00:00         0.0       few clouds  20.290000         3
# 2014-08-20 15:00:00         2.0     sky is clear  22.602500         3
# 2014-08-20 16:00:00         1.0     sky is clear  23.682000         3
# 2014-08-20 17:00:00         1.0     sky is clear  24.266000         3
# 2014-07-30 03:00:00         2.0     sky is clear  20.848500         3
# 2014-05-25 14:00:00         0.0       few clouds  21.150000         3
# 2014-05-25 15:00:00         2.0       few clouds  23.790000         3
# 2014-08-20 13:00:00         2.0     sky is clear  21.269333         3
# 2014-06-13 23:00:00         2.0     sky is clear  21.450000         3
#
#                      TempRate  WindRate  Overall Weather
# datetime
# 2016-04-26 12:00:00         0         2        2     Bad
# 2016-02-27 15:00:00         0         2        2     Bad
# 2015-01-03 16:00:00         0         2        2     Bad
# 2013-05-24 14:00:00         0         2        2     Bad
# 2014-03-19 00:00:00         0         2        2     Bad
# 2014-03-19 01:00:00         0         2        2     Bad
# 2015-01-04 02:00:00         0         2        2     Bad
# 2014-03-19 08:00:00         0         2        2     Bad
# 2015-01-04 04:00:00         0         2        2     Bad
# 2014-03-19 09:00:00         0         2        2     Bad
# 2014-03-19 11:00:00         0         2        2     Bad
# 2014-03-19 12:00:00         0         2        2     Bad
# 2014-03-19 13:00:00         0         2        2     Bad
# 2015-01-04 05:00:00         0         2        2     Bad
# 2014-03-19 14:00:00         0         2        2     Bad
# 2014-03-19 15:00:00         0         2        2     Bad
# 2014-03-19 16:00:00         0         2        2     Bad
# 2015-01-04 06:00:00         0         2        2     Bad
# 2014-03-19 17:00:00         0         2        2     Bad
# 2014-03-19 23:00:00         0         2        2     Bad
# 2014-03-20 00:00:00         0         2        2     Bad
# 2014-03-20 01:00:00         0         2        2     Bad
# 2014-03-20 03:00:00         0         2        2     Bad
# 2015-01-04 09:00:00         0         2        2     Bad
# 2015-01-03 14:00:00         0         2        2     Bad
# 2014-03-20 04:00:00         0         2        2     Bad
# 2015-01-03 13:00:00         0         2        2     Bad
# 2015-01-03 12:00:00         0         2        2     Bad
# 2016-03-01 05:00:00         0         2        2     Bad
# 2017-03-04 09:00:00         0         2        2     Bad
# ...                       ...       ...      ...     ...
# 2014-05-25 20:00:00         3         3        9    Good
# 2014-07-30 01:00:00         3         3        9    Good
# 2017-07-24 04:00:00         3         3        9    Good
# 2014-07-30 16:00:00         3         3        9    Good
# 2014-08-20 05:00:00         3         3        9    Good
# 2014-08-20 06:00:00         3         3        9    Good
# 2014-08-20 07:00:00         3         3        9    Good
# 2014-08-20 08:00:00         3         3        9    Good
# 2014-08-20 09:00:00         3         3        9    Good
# 2014-08-20 10:00:00         3         3        9    Good
# 2014-08-20 11:00:00         3         3        9    Good
# 2013-09-10 03:00:00         3         3        9    Good
# 2014-08-20 12:00:00         3         3        9    Good
# 2014-05-24 17:00:00         3         3        9    Good
# 2014-05-25 18:00:00         3         3        9    Good
# 2014-05-24 18:00:00         3         3        9    Good
# 2014-05-24 19:00:00         3         3        9    Good
# 2014-08-20 14:00:00         3         3        9    Good
# 2014-05-24 20:00:00         3         3        9    Good
# 2014-05-24 21:00:00         3         3        9    Good
# 2014-05-24 22:00:00         3         3        9    Good
# 2014-05-24 23:00:00         3         3        9    Good
# 2014-08-20 15:00:00         3         3        9    Good
# 2014-08-20 16:00:00         3         3        9    Good
# 2014-08-20 17:00:00         3         3        9    Good
# 2014-07-30 03:00:00         3         3        9    Good
# 2014-05-25 14:00:00         3         3        9    Good
# 2014-05-25 15:00:00         3         3        9    Good
# 2014-08-20 13:00:00         3         3        9    Good
# 2014-06-13 23:00:00         3         3        9    Good
#
# [45252 rows x 8 columns]

# %% [markdown]
# We give an overall count of the weather grades. Unsurprsingly, there is more bad weather than either moderate or good. This would be because a lot of the hours would be overnight when the temperature is lower and the sun is in.

# %%
wea1 = chiWea.groupby('Weather')[('Overall')].count()
wea1.sort_values(ascending=False)
# Out:
# Weather
# Bad         25374
# Moderate    13160
# Good         6718
# Name: Overall, dtype: int64

# %% [markdown]
# We save this to a new csv, where it will be used for analysis.

# %%
chiWea.to_csv('../../data/prep/300_ChiWea.csv')
